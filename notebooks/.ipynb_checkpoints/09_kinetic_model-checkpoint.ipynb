# %% [markdown]
# ## Import lib

# %%
# !pip install tellurium

# %%
import tellurium as te

# %% [markdown]
# ## Equation and parameters

# %% [markdown]
# ### Arabinose Conversion by L-AI (L-Arabinose isomerase)

# %% [markdown]
# L-AI expression using weak anderson promoter J23106
# $$
# \frac{d}{dt}[A_i]= \alpha - \gamma_{A_i}[A_i]\\
# \alpha = \frac{k_1k_0}{\delta_m}
# $$
# where: <br>
# - $A_i$ = L-AI

# %%
Ai      = 1e-3    # L-AI (initial concentration)
y_Ai    = 1.7e-3  # L-AI decay rate
k_tl_Ai = 1e-2    # L-AI mRNA translation rate
k_tc_Ai = 9e-5    # L-AI population-averaged transcription rate
y_m_Ai  = 1.7e-3  # L-AI mRNA decay rate

# %% [markdown]
# L-Arabinose $\rightarrow$ L-Ribulose reaction by L-AI
# $$
# A_i + A_1 \rightleftharpoons A_iA_1 \rightarrow A_i + R\\
# $$
# where : <br>
# - $A_1$ = L-Arabinose inside cell
# - $R$   = L-Ribulose

# %%
A1       = 1e-5      # L-Arabinose inside cell (initial concentration)
k_f_AiA1 = 0.00012   # forward reaction rate (formation of AiA1 complex)
k_r_AiA1 = 0.0000012 # reverse reaction rate (reduction of AiA1 complex)
k_cat_R  = 8.167     # catalytic rate (reduction from AiA1 to A1 and R)

# %% [markdown]
# ### HCN Production with insert arabinose regulated hcnABC operone

# %% [markdown]
# Transcription Factor Complex formation (Arabinose-AraC complex)
# $$
# A_0 \rightarrow A_1 \rightarrow \emptyset\\
# A_1 + AraC \rightleftharpoons A_1.AraC \\
# $$
# where : <br>
# - $A_0$ = L-Arabinose outside cell

# %%
A0         = 200     # L-Arabinose outside cell (initial concentration), in Molar
AraCTotal  = 1e-8    # Total AraC in cell (constant)
A1AraC     = 1e-8    # L-Arabinose-AraC complex (initial concentration), in Molar
k_diff_A   = 7e-18   # L-Arabinose diffusion rate, in Mole/cell/30 minute
k_f_A1AraC = 1.2e-4  # forward reaction rate (formation of A_1.AraC complex), in s^-1
k_r_A1AraC = 1.2e-4  # reverse reaction rate (reduction A_1.AraC), in s^-1
y_A1       = 3.46e-5 # L-Arabinose inside cell decay rate, in s^-1

# %% [markdown]
# HCN synthase formation (using $A_1.AraC$ complex)
# $$
# \frac{d}{dt}[HCN_{cell}]= \alpha_0 + \alpha\frac{[A_1.AraC]^n}{K_m^n + [A_1.AraC]^n} - \gamma[HCN_{cell}]\\
# $$
# HCN synthase formation (using $CviR.AHL$ complex)
# $$
# \frac{d}{dt}[HCN_{cell}]= \beta_0 + \beta\frac{[CviR.AHL]^n}{K_q^n + [CviR.AHL]^n} - \gamma[HCN_{cell}]\\
# $$
# HCN synthase formation (using both complex)
# $$
# \frac{d}{dt}[HCN_{cell}]= \alpha_0 + \alpha\frac{[A_1.AraC]^n}{K_m^n + [A_1.AraC]^n} + \beta_0 + \beta\frac{[CviR.AHL]^n}{K_q^n + [CviR.AHL]^n} - \gamma[HCN_{cell}]\\
# $$
# where : <br>
# - $HCN_{cell}$ = HCN synthase inside cell

# %%
HCN_cell   = 1e-3   # HCN synthase intracellular (initial concentration), in Molar
a          = 10     # maximal transcription rate (using A_1.AraC)
b          = 1e-2   # maximal transcription rate (using CviR.AHL)
a0         = 0.01   # basal transcription (using A_1.AraC)
b0         = 0.01   # basal transcription (using CviR.AHL)
n          = 2.26   # hill coefficient
K_m        = 1e-9   # A_1.AraC complex concentration occupying half of the binding sites 
K_q        = 1e-9   # CviR.AHL complex concentration occupying half of the binding sites 
y_HCN_cell = 5.6e-5 # HCN synthase decay rate

# %% [markdown]
# HCN syntase transition
# $$
# HCN_{cell} \rightleftharpoons HCN_{memb}
# $$
# where : <br>
# - $HCN_{memb}$ = HCN synthase in membrane

# %%
HCN_memb  = 1e-3 # HCN synthase membran (initial concentration)
k_on_HCN  = 9e-3 # HCN syntase activation rate
k_off_HCN = 1e-8 # HCN syntase inactivation rate

# %% [markdown]
# HCN Production
# $$
# HCN_{memb} + G \rightleftharpoons C_1 \\
# C_1 + 2Ac \rightleftharpoons C_2 \\
# C_2 \rightarrow HCN + CO_2 + 2AcH_2 + HCN_{memb} \\
# $$
# where: <br>
# - $G$ = Glycine
# - $C_1$ = $HCN_{memb}$-Glycine complex
# - $C_2$ = $C_1$-Acceptor complex
# - $Ac$ = Acceptor

# %%
G      =  1e-3 # Glycine (initial concentration)
C1     =  1e-3 # HCNmemb-Glycine complex (initial concentration)
C2     =  1e-3 # C1-Acceptors complex (initial concentration)
Ac     =  1e-5 # Acceptors (initial concentration)
k_f_C1 =  1e-8 # forward reaction rate (formation of C1)
k_f_C2 =  1e-8 # forward reaction rate (formation of C2)
k_r_C1 =  1e-8 # reverse reaction rate (reduction of C1)
k_r_C2 =  1e-8 # reverse reaction rate (reduction of C2)
k_h    =  9e-3 # HCN creation rate

# %% [markdown]
# ### HCN Degradation by rhodanese, regulation by arabinose & TetR

# %% [markdown]
# Rhodanese formation
# $$
# \frac{d}{dt}[Rho]= \theta_0 + \theta\frac{K_r^n}{K_r^n + [TetR_2]^n} - \gamma[Rho]\\
# $$
# Because $[TetR_2]=0$, then
# $$
# \frac{d}{dt}[Rho]= \theta_0 + \theta - \gamma[Rho]\\
# $$
# Rhodanese production active when Arabinose ($A_1$) concentration is below $\rho$
# where : <br>
# - $Rho$ = Rhodanese

# %%
Rho   =  1e-3   # Rhodanese (initial concentration)
p     =  5e-6   # maximum value of A1 to trigger rhodanese
t     =  1e-2   # maximal transcription rate
t0    =  1e-2   # basal transcription
y_Rho =  5.6e-5 # Rhodanese decay rate

# %% [markdown]
# HCN Degradation
# $$
# HCN \rightarrow H + CN \\
# Rho + S_2O_3 \rightleftharpoons RhoS_2O_3 \rightarrow RhoS + SO_3\\
# RhoS + CN \rightarrow Rho + SCN \\
# $$

# %%
S2O3    = 1e-3   # S2O3 (initial concentration)
k_f_Rho = 0.48   # forward reaction rate (formation of Rhodanese-S2O3)
k_r_Rho = 1.6e-3 # reverse reaction rate (reduction of Rhodanese-S2O3)
k_x     = 1.3e-2 # forward reaction rate (formation of RhoS and SO3)
k_y     = 0.055  # forward reaction rate (formation of SCN)

# %% [markdown]
# ## Modelling

# %%
raw_model = f'''
// Transcription Translation process
// d/dt [E] = a - y[E]
model formation_reaction(E, a, y)
  J0:   -> E ; a     ;
  J1: E ->   ; y * E ;
end

// Michaelis-menten equation
// E + S <-> ES -> E + P
model michaelis_menten_reaction(E, S, kf, kr, kcat)
  J0: E + S -> ES     ; kf * E * S ;
  J1: ES    -> E + S  ; kr * ES    ;
  J2: ES    -> E + P  ; kcat * ES  ;
  ES = 0;
  P  = 0;
end

// A1AraC complex (diffusion)
model arabinose_arac_diffusion(A0, A1, A1AraC, AraCTotal, kdiff, kf, kr, y)
  J1: A0         -> A1         ; kdiff * (A0 - A1)                 ;
  J2: A1         ->            ; y * A1                            ;
  J3: A1 + AraC  -> A1AraC     ; kf * A1 * (AraCTotal - A1AraC)    ;
  J4: A1AraC     -> A1 + AraC  ; kr * A1AraC                       ;
  AraC = AraCTotal - A1AraC;
end

// Intracell-membran transition
model intracell_membran_transition(Ec, Em, kon, koff)
  J1: Ec -> Em ; kon * Ec  ;
  J2: Em -> Ec ; koff * Em ;
end

// HCN production
model hcn_production(E, G, C1, C2, Ac, HCN, kf1, kr1, kf2, kr2, kh)
  J1: E + G    -> C1                    ; kf1 * E * G     ;
  J2: C1       -> E + G                 ; kr1 * C1        ;
  J3: C1 + 2Ac -> C2                    ; kf2 * C1 * Ac^2 ;
  J4: C2       -> C1 + 2Ac              ; kr2 * C2        ;
  J5: C2       -> HCN + CO2 + 2AcH2 + E ; kh * C2         ;
  CO2  = 0;
  AcH2 = 0;
end

// HCN degradation
model hcn_degradation(E, S1, CN, k1, k2, k3, k4)
  J1: E + S1   -> ES1        ; k1 * E * S1   ;
  J2: ES1      -> E + S1     ; k2 * ES1      ;
  J3: ES1      -> ES2 + $SO3 ; k3 * ES1      ;
  J4: ES2 + CN -> E + $SCN   ; k4 * ES2 * CN ;
  ES1 = 0;
  ES2 = 0;
  SO3 = 0;
  SCN = 0;
end

// Full reaction
model full_reaction
  // ---------------------------- Species ---------------------------------------------

  species Ai, A1;
  species A0, A1AraC;
  species HCNc, HCNm;
  species G, C1, C2, Ac, HCN;
  species Rho, S2O3;

  //---------------------------- Reactions --------------------------------------------

  J_F_Ai       : formation_reaction(Ai, alpha_Ai, yAi);
  J_MM_R       : michaelis_menten_reaction(Ai, A1, kf0, kr0, kcat);
  J_Diff       : arabinose_arac_diffusion(A0, A1, A1AraC, AraCTotal, kdiff, kf1, kr1, yA1);
  
  J_F_HCNc_ara : formation_reaction(HCNc, alpha_arac, yHCN); //
  # J_F_HCNc_cvi : formation_reaction(HCNc, alpha_cvir, yHCN); // Pilih salah satu
  # J_F_HCNc_all : formation_reaction(HCNc, alpha_both, yHCN); //

  J_IM_HCN     : intracell_membran_transition(HCNc, HCNm, kon, koff);
  J_HCN        : hcn_production(HCNm, G, C1, C2, Ac, HCN, kf2, kr2, kf3, kr3, kh);

  J_F_Rho      : formation_reaction(Rho, alpha_rho, yRho);
  J_HCN_D      : hcn_degradation(Rho, S2O3, HCN, kf4, kr4, kx, ky)

  //------------------------------- Event --------------------------------------------

  E0 : at (A1 < {p}) : alpha_rho = {t0} + {t};

  // ----------------------------- Values ---------------------------------------------

  Ai       = {Ai};
  yAi      = {y_Ai};
  alpha_Ai = {k_tl_Ai} * {k_tc_Ai} / {y_m_Ai};

  A1 = {A1}        ;
  kf0 = {k_f_AiA1} ; kr0 = {k_r_AiA1} ; kcat = {k_cat_R} ;

  A0 = {A0}          ; AraCTotal = {AraCTotal} ; A1AraC = {A1AraC}  ;
  kdiff = {k_diff_A} ; kf1 = {k_f_A1AraC}      ; kr1 = {k_r_A1AraC} ;
  yA1 = {y_A1}       ;

  HCNc = {HCN_cell};
  CviR = 0;
  a = {a}; a0 = {a0}; Km = {K_m}; n0 = {n};
  b = {b}; b0 = {b0}; Kq = {K_q}; n1 = {n};
  alpha_arac := a0 + a * A1AraC^n0 / (Km^n0 + A1AraC^n0);
  alpha_cvir := b0 + b * CviR^n1 / (Kq^n1 + CviR^n1);
  alpha_both := alpha_arac + alpha_cvir;
  yHCN = {y_HCN_cell};

  HCNm = {HCN_memb};
  kon = {k_on_HCN}; koff = {k_off_HCN};

  HCN = 0        ;
  G = {G}        ; Ac = {Ac}      ;
  C1 = {C1}      ; C2 = {C2}      ; 
  kf2 = {k_f_C1} ; kr2 = {k_r_C1} ;
  kf3 = {k_f_C2} ; kr3 = {k_r_C2} ;
  kh = {k_h}     ;

  p = {p}; Rho = {Rho};
  t = {t}; t0 = {t0};
  _a = t0 + t; alpha_rho = 0;
  yRho = {y_Rho};
    
  S2O3 = {S2O3}   ;
  kf4 = {k_f_Rho} ; kr4 = {k_r_Rho} ;
  kx  = {k_x}     ; ky = {k_y}      ;

end
'''

model = te.loada(raw_model)

# %%
time_end =  14400 #@param {type:"integer"}
time_step =  14400 #@param {type:"integer"}

# %%
res = model.simulate(0, time_end, time_step)
model.plot(figsize=(8,4.5), logy=True)
model.reset()

# %%
x = res[:, res.colnames.index('time')]
A1 = res[:, res.colnames.index('[A1]')]
Rho = res[:, res.colnames.index('[Rho]')]
HCN = res[:, res.colnames.index('[HCN]')]

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(3)
fig.set_size_inches(10, 20)
ax1.set_title('L-Arabinose inside cell')
ax1.plot(x, A1)

ax2.set_title('Rhodanese')
ax2.plot(x, Rho)

ax3.set_title('HCN')
ax3.plot(x, HCN)

plt.savefig('modelling_v1.png')
plt.show()
