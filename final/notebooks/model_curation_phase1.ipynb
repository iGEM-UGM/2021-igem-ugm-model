# %%
from cameo import load_model
from cameo import fba

import escher
from escher import Builder

# %%
# load Chromobacterium model
model = load_model('../models/iDB858_updated1.xml')
model
# Out:
# <Model M_iDB858 at 0x1f7062ceb20>

# %% [markdown]
# Number of metabolites: **1003**
# Number of reactions: **1330**

# %%
# simulasi model
s = fba(model)
flux = s.fluxes.to_frame()
s.objective_value
# Out:
# 0.2515998481207547

# %%
# map from author
builder_scratch = Builder(
    map_json = '../maps/cv_Core metabolism_MAP.json',
    model = model,
    reaction_data = s.fluxes
)
builder_scratch
# Out:
# Builder(reaction_data={'rxn12008_c': 0.00233685938934557, 'rxn00541_c': 0.0, 'rxn00225_c': 0.0, 'rxn01674_c': …

# %% [markdown]
# Here we can see that many reactions and metabolite does not match map id

# %%
# Let's look at map data
import json
with open ("../maps/cv_Core metabolism_MAP.json", "r") as f:
    data = json.loads(f.read())

# %%
# how many reactions and metabolites in the map?
len_reaction = len(data[1]["reactions"])
len_metabolites = len([m for m in data[1]["nodes"] if data[1]["nodes"][m]["node_type"] == "metabolite"])
print("reactions:", len_reaction, "metabolites:", len_metabolites)
# Out:
# reactions: 139 metabolites: 357

# %% [markdown]
# ## Mapping Metabolites
# We would like to match the metabolites id with the metabolites in the model

# %%
# make a list of metabolites
met_model = {m.id: m.name for m in model.metabolites}
met_map = {data[1]["nodes"][m]['bigg_id']: data[1]["nodes"][m]["name"] for m in data[1]["nodes"] if data[1]["nodes"][m]["node_type"] == "metabolite"}

# find mismatch
mismatch_metabolites = [met for met in met_map.keys() if not met in met_model.keys()]
print(f"found {len(mismatch_metabolites)} mismatch:", mismatch_metabolites)
# Out:
# found 23 mismatch: ['34hpp_c', 'gln_DASH_L_c', 'glu_DASH_L_c', 'phe_DASH_L_c', 'tyr_DASH_L_c', 'phe_DASH_L_e', 'tyr_DASH_L_e', 'ser_DASH_L_c', 'trp_DASH_L_c', 'trp_DASH_L_e', '2i3ip_c', 'pdvnate_c', 'chpy_c', 'pvnate_c', 'vnate_c', 'vio_c', 'chpy_e', 'dvnate_c', 'dvio_c', 'dvio_e', 'provio_c', 'provio_e', 'vio_e']

# %% [markdown]
# Not bad, only 23 mismatches in the map, let's find the correct name in the model

# %%
for met in met_model.keys():
    for miss in mismatch_metabolites:
        query = miss.split("_")[0]
        if query in met_model[met]:
            print(query, met, met_model[met])
# Out:
# glu acgam1p_c N-Acetyl-D-glucosamine 1-phosphate
# ser achms_c O Acetyl L homoserine C6H11NO4
# glu dtdpglu_c DTDPglucose
# glu sucglu_c N2-Succinyl-L-glutamate
# glu sucgsa_c N2-Succinyl-L-glutamate 5-semialdehyde
# glu uacgam_c UDP-N-acetyl-D-glucosamine
# glu u3aga_c UDP-3-O-(3-hydroxytetradecanoyl)-N-acetylglucosamine
# tyr ibcoa_c Isobutyryl-CoA
# tyr ibcoa_c Isobutyryl-CoA
# glu hpglu_c Tetrahydropteroyltri L glutamate C24H34N8O12
# glu mhpglu_c 5 Methyltetrahydropteroyltri L glutamate C25H36N8O12
# ser hom__L_c L-Homoserine
# glu ugmd_c UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate
# glu ugmda_c UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# glu akg_c 2-Oxoglutarate
# glu uaagmda_c Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-ala-D-glu-meso-2,6-diaminopimeloyl-D-ala-D-ala
# ser acser_c O-Acetyl-L-serine
# tyr butACP_c Butyryl-ACP (n-C4:0ACP)
# tyr butACP_c Butyryl-ACP (n-C4:0ACP)
# glu g6p_B_c Beta D glucose 6 phosphate C6H11O9P
# glu 6pgl_c 6-phospho-D-glucono-1,5-lactone
# tyr 3hmbcoa_c (S)-3-Hydroxy-2-methylbutyryl-CoA
# tyr 3hmbcoa_c (S)-3-Hydroxy-2-methylbutyryl-CoA
# glu ala_L_glu__L_c ala-L-glu-L
# glu forglu_c N-Formimidoyl-L-glutamate
# glu u23ga_c UDP-2,3-bis(3-hydroxytetradecanoyl)glucosamine
# tyr cpd11495_c 2-methylbutyryl-ACP
# tyr cpd11495_c 2-methylbutyryl-ACP
# ser phom_c O-Phospho-L-homoserine
# glu dtdp4d6dg_c DTDP-4-dehydro-6-deoxy-D-glucose
# glu ala_L_glu__L_e ala-L-glu-L
# phe 2h34hppr_c p-hydroxyphenylpyruvate
# phe 2h34hppr_c p-hydroxyphenylpyruvate
# glu uamag_c UDP-N-acetylmuramoyl-L-alanyl-D-glutamate
# glu uaccg_c UDP-N-acetyl-3-O-(1-carboxyvinyl)-D-glucosamine
# phe 2omph_c 2-Octaprenyl-6-methoxyphenol
# phe 2omph_c 2-Octaprenyl-6-methoxyphenol
# phe 2ohph_c 2-Octaprenyl-6-hydroxyphenol
# phe 2ohph_c 2-Octaprenyl-6-hydroxyphenol
# phe 2cpr5p_c 1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate
# phe 2cpr5p_c 1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate
# glu glc_bD_c Beta D-glucose
# glu 6pgc_c 6-Phospho-D-gluconate
# glu 2ddg6p_c 2-Dehydro-3-deoxy-D-gluconate 6-phosphate
# phe pphn_c Prephenate
# phe pphn_c Prephenate
# ser ps180_c phosphatidylserine dioctadecanoyl
# glu hmgcoa_c Hydroxymethylglutaryl CoA C27H39N7O20P3S
# glu uagmda_c Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# ser cpd15690_c Dianteisoheptadecanoylphosphatidylserine
# glu 3mgcoa_c 3-Methylglutaconyl-CoA
# glu udpg_c UDPglucose
# ser pser__L_c O-Phospho-L-serine
# glu gly_glu__L_c gly-glu-L
# glu gly_glu__L_e gly-glu-L
# ser cpd15689_c Diisoheptadecanoylphosphatidylserine
# glu gicolipa_c glucosyl-inner core oligosaccharide lipid A
# glu acgam6p_c N-Acetyl-D-glucosamine 6-phosphate
# glu acglu_c N-Acetyl-L-glutamate
# phe 2oph_c 2-Octaprenylphenol
# phe 2oph_c 2-Octaprenylphenol
# glu acg5sa_c N-Acetyl-L-glutamate 5-semialdehyde
# glu acg5p_c N-Acetyl-L-glutamyl 5-phosphate
# glu lipidA_c 2,3,23-Tetrakis(beta-hydroxymyristoyl)-D-glucosaminyl-1,6-beta-D-glucosamine 1,4-bisphosphate
# glu acgam_e N-Acetyl-D-glucosamine
# tyr cpd04539_c 2-Amino-3-oxo-4-phosphonooxybutyrate
# tyr cpd04539_c 2-Amino-3-oxo-4-phosphonooxybutyrate
# glu u3hga_c UDP-3-O-(3-hydroxytetradecanoyl)-D-glucosamine
# glu gggagicolipa_c glucosyl-glucosyl-galactosyl-glucosyl-inner core oligosaccharide lipid A
# vio mDB_pdvnate_c Protodeoxyviolaceinate
# vio mDB_pdvnate_c Protodeoxyviolaceinate
# vio mDB_pvnate_c Protoviolaceinate
# vio mDB_pvnate_c Protoviolaceinate
# vio mDB_dvnate_c Deoxyviolaceinate
# vio mDB_dvnate_c Deoxyviolaceinate
# vio mDB_dvio_c Deoxyviolacein
# vio mDB_dvio_c Deoxyviolacein
# vio mDB_prodvio_c Prodeoxyviolacein
# vio mDB_prodvio_c Prodeoxyviolacein
# vio mDB_dvio_e Deoxyviolacein
# vio mDB_dvio_e Deoxyviolacein
# vio mDB_prodvio_e Prodeoxyviolacein
# vio mDB_prodvio_e Prodeoxyviolacein
# glu gthox_c Oxidized glutathione
# ser ps160_c Phosphatidylserine (dihexadecanoyl, n-C16:0)
# ser ps181_c Phosphatidylserine (dioctadec-11-enoyl, n-C18:1)
# ser ps140_c phosphatidylserine ditetradecanoyl
# ser ps120_c Phosphatidylserine (didodecanoyl, n-C12:0)
# ser ps161_c Phosphatidylserine (dihexadec-9-enoyl, n-C16:1)
# ser ps141_c phosphatidylserine ditetradec-7-enoyl
# glu akg_e 2-Oxoglutarate

# %% [markdown]
# Try to explore which one matches, sometimes need manual curation, and came up with this [table](../tables/metabolite_map.csv). Hint: the amino acid starts with uppercase.

# %%
import pandas as pd

# %%
metabolite_map = pd.read_csv("../tables/metabolite_map.csv").dropna()
metabolite_map = metabolite_map.set_index("map_id")
metabolite_map
# Out:
#                  map_name       model_id  \
# map_id
# 2i3ip_c          2i3ip[c]    mDB_2i3ip_c
# 34hpp_c          34hpp[c]     2h34hppr_c
# dvio_c            dvio[c]     mDB_dvio_c
# dvio_e            dvio[e]     mDB_dvio_e
# dvnate_c        dvnate[c]   mDB_dvnate_c
# gln_DASH_L_c  L-Glutamine       gln__L_c
# glu_DASH_L_c  L-Glutamate       glu__L_c
# pdvnate_c      pdvnate[c]  mDB_pdvnate_c
# phe_DASH_L_c     phe-L[c]       phe__L_c
# phe_DASH_L_e     phe-L[e]       phe__L_e
# provio_c        provio[c]  mDB_prodvio_c
# provio_e        provio[e]  mDB_prodvio_e
# pvnate_c        pvnate[c]   mDB_pvnate_c
# ser_DASH_L_c     ser-L[c]       ser__L_c
# trp_DASH_L_c     trp-L[c]       trp__L_c
# trp_DASH_L_e     trp-L[e]       trp__L_e
# tyr_DASH_L_c     tyr-L[c]       tyr__L_c
# tyr_DASH_L_e     tyr-L[e]       tyr__L_e
# vio_c              vio[c]      mDB_vio_c
# vio_e              vio[e]      mDB_vio_e
# vnate_c          vnate[c]    mDB_vnate_c
#
#                                          model_name
# map_id
# 2i3ip_c       2 - imino - 3- (indol-3-yl)propanoate
# 34hpp_c                     p-hydroxyphenylpyruvate
# dvio_c                               Deoxyviolacein
# dvio_e                               Deoxyviolacein
# dvnate_c                          Deoxyviolaceinate
# gln_DASH_L_c                            L-Glutamine
# glu_DASH_L_c                            L-Glutamate
# pdvnate_c                    Protodeoxyviolaceinate
# phe_DASH_L_c                        L-Phenylalanine
# phe_DASH_L_e                        L-Phenylalanine
# provio_c                          Prodeoxyviolacein
# provio_e                          Prodeoxyviolacein
# pvnate_c                          Protoviolaceinate
# ser_DASH_L_c                               L-Serine
# trp_DASH_L_c                           L-Tryptophan
# trp_DASH_L_e                           L-Tryptophan
# tyr_DASH_L_c                             L-Tyrosine
# tyr_DASH_L_e                             L-Tyrosine
# vio_c                                     Violacein
# vio_e                                     Violacein
# vnate_c                                Violaceinate

# %%
# replace metabolite value with model
for query in metabolite_map.index:
    for r in data[1]["reactions"]:
        for num, m in enumerate(data[1]["reactions"][r]["metabolites"]):
            if data[1]["reactions"][r]["metabolites"][num]["bigg_id"] == query:
                print("replacing:", query, "-->", metabolite_map.loc[query, "model_id"])
                #print(r, num, data[1]["reactions"][r]["metabolites"][num]["bigg_id"])
                data[1]["reactions"][r]["metabolites"][num]["bigg_id"] = metabolite_map.loc[query, "model_id"]
                print(r, num, "result:", data[1]["reactions"][r]["metabolites"][num]["bigg_id"])
                print("------------------")
    for n in data[1]["nodes"]:
        if data[1]["nodes"][n]["node_type"] == "metabolite":
            if data[1]["nodes"][n]["bigg_id"] == query:
                data[1]["nodes"][n]["bigg_id"] = metabolite_map.loc[query, "model_id"]
                data[1]["nodes"][n]["name"] = metabolite_map.loc[query, "model_name"]    
                print(n, data[1]["nodes"][n]["bigg_id"], metabolite_map.loc[query, "model_id"])
# Out:
# replacing: 2i3ip_c --> mDB_2i3ip_c
# 1577625 0 result: mDB_2i3ip_c
# ------------------
# replacing: 2i3ip_c --> mDB_2i3ip_c
# 1577626 0 result: mDB_2i3ip_c
# ------------------
# replacing: 2i3ip_c --> mDB_2i3ip_c
# 1577627 0 result: mDB_2i3ip_c
# ------------------
# 1577557 mDB_2i3ip_c mDB_2i3ip_c
# replacing: 34hpp_c --> 2h34hppr_c
# 1577570 1 result: 2h34hppr_c
# ------------------
# replacing: 34hpp_c --> 2h34hppr_c
# 1577575 1 result: 2h34hppr_c
# ------------------
# 1577233 2h34hppr_c 2h34hppr_c
# replacing: dvio_c --> mDB_dvio_c
# 1577640 2 result: mDB_dvio_c
# ------------------
# replacing: dvio_c --> mDB_dvio_c
# 1577641 1 result: mDB_dvio_c
# ------------------
# 1577660 mDB_dvio_c mDB_dvio_c
# replacing: dvio_e --> mDB_dvio_e
# 1577641 0 result: mDB_dvio_e
# ------------------
# replacing: dvio_e --> mDB_dvio_e
# 1577642 0 result: mDB_dvio_e
# ------------------
# 1577666 mDB_dvio_e mDB_dvio_e
# replacing: dvnate_c --> mDB_dvnate_c
# 1577638 6 result: mDB_dvnate_c
# ------------------
# replacing: dvnate_c --> mDB_dvnate_c
# 1577640 4 result: mDB_dvnate_c
# ------------------
# 1577646 mDB_dvnate_c mDB_dvnate_c
# replacing: gln_DASH_L_c --> gln__L_c
# 1577573 2 result: gln__L_c
# ------------------
# 1577257 gln__L_c gln__L_c
# replacing: glu_DASH_L_c --> glu__L_c
# 1577573 5 result: glu__L_c
# ------------------
# replacing: glu_DASH_L_c --> glu__L_c
# 1577574 2 result: glu__L_c
# ------------------
# replacing: glu_DASH_L_c --> glu__L_c
# 1577575 2 result: glu__L_c
# ------------------
# 1577259 glu__L_c glu__L_c
# 1577264 glu__L_c glu__L_c
# 1577270 glu__L_c glu__L_c
# replacing: pdvnate_c --> mDB_pdvnate_c
# 1577626 3 result: mDB_pdvnate_c
# ------------------
# replacing: pdvnate_c --> mDB_pdvnate_c
# 1577630 4 result: mDB_pdvnate_c
# ------------------
# replacing: pdvnate_c --> mDB_pdvnate_c
# 1577638 4 result: mDB_pdvnate_c
# ------------------
# 1577566 mDB_pdvnate_c mDB_pdvnate_c
# replacing: phe_DASH_L_c --> phe__L_c
# 1577574 3 result: phe__L_c
# ------------------
# replacing: phe_DASH_L_c --> phe__L_c
# 1577599 3 result: phe__L_c
# ------------------
# 1577265 phe__L_c phe__L_c
# replacing: phe_DASH_L_e --> phe__L_e
# 1577599 0 result: phe__L_e
# ------------------
# replacing: phe_DASH_L_e --> phe__L_e
# 1577600 0 result: phe__L_e
# ------------------
# 1577414 phe__L_e phe__L_e
# replacing: provio_c --> mDB_prodvio_c
# 1577643 2 result: mDB_prodvio_c
# ------------------
# replacing: provio_c --> mDB_prodvio_c
# 1577644 0 result: mDB_prodvio_c
# ------------------
# 1577675 mDB_prodvio_c mDB_prodvio_c
# replacing: provio_e --> mDB_prodvio_e
# 1577644 1 result: mDB_prodvio_e
# ------------------
# replacing: provio_e --> mDB_prodvio_e
# 1577645 0 result: mDB_prodvio_e
# ------------------
# 1577681 mDB_prodvio_e mDB_prodvio_e
# replacing: pvnate_c --> mDB_pvnate_c
# 1577630 5 result: mDB_pvnate_c
# ------------------
# replacing: pvnate_c --> mDB_pvnate_c
# 1577632 5 result: mDB_pvnate_c
# ------------------
# replacing: pvnate_c --> mDB_pvnate_c
# 1577643 3 result: mDB_pvnate_c
# ------------------
# 1577596 mDB_pvnate_c mDB_pvnate_c
# replacing: ser_DASH_L_c --> ser__L_c
# 1577609 1 result: ser__L_c
# ------------------
# replacing: ser_DASH_L_c --> ser__L_c
# 1577611 1 result: ser__L_c
# ------------------
# 1577481 ser__L_c ser__L_c
# replacing: trp_DASH_L_c --> trp__L_c
# 1577609 3 result: trp__L_c
# ------------------
# replacing: trp_DASH_L_c --> trp__L_c
# 1577611 3 result: trp__L_c
# ------------------
# replacing: trp_DASH_L_c --> trp__L_c
# 1577614 3 result: trp__L_c
# ------------------
# replacing: trp_DASH_L_c --> trp__L_c
# 1577619 3 result: trp__L_c
# ------------------
# replacing: trp_DASH_L_c --> trp__L_c
# 1577625 3 result: trp__L_c
# ------------------
# 1577482 trp__L_c trp__L_c
# replacing: trp_DASH_L_e --> trp__L_e
# 1577619 0 result: trp__L_e
# ------------------
# replacing: trp_DASH_L_e --> trp__L_e
# 1577620 0 result: trp__L_e
# ------------------
# 1577529 trp__L_e trp__L_e
# replacing: tyr_DASH_L_c --> tyr__L_c
# 1577575 3 result: tyr__L_c
# ------------------
# replacing: tyr_DASH_L_c --> tyr__L_c
# 1577601 3 result: tyr__L_c
# ------------------
# 1577271 tyr__L_c tyr__L_c
# replacing: tyr_DASH_L_e --> tyr__L_e
# 1577601 0 result: tyr__L_e
# ------------------
# replacing: tyr_DASH_L_e --> tyr__L_e
# 1577602 0 result: tyr__L_e
# ------------------
# 1577423 tyr__L_e tyr__L_e
# replacing: vio_c --> mDB_vio_c
# 1577633 4 result: mDB_vio_c
# ------------------
# replacing: vio_c --> mDB_vio_c
# 1577646 0 result: mDB_vio_c
# ------------------
# 1577622 mDB_vio_c mDB_vio_c
# replacing: vio_e --> mDB_vio_e
# 1577646 1 result: mDB_vio_e
# ------------------
# replacing: vio_e --> mDB_vio_e
# 1577647 0 result: mDB_vio_e
# ------------------
# 1577688 mDB_vio_e mDB_vio_e
# replacing: vnate_c --> mDB_vnate_c
# 1577632 4 result: mDB_vnate_c
# ------------------
# replacing: vnate_c --> mDB_vnate_c
# 1577633 2 result: mDB_vnate_c
# ------------------
# 1577614 mDB_vnate_c mDB_vnate_c

# %%
with open('../results/edited_map.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
# map from author
builder_scratch = Builder(
    map_json = '../results/edited_map.json',
    model = model,
    reaction_data = s.fluxes
)
builder_scratch
# Out:
# Builder(reaction_data={'rxn12008_c': 0.00233685938934557, 'rxn00541_c': 0.0, 'rxn00225_c': 0.0, 'rxn01674_c': …

# %% [markdown]
# ## Mapping Reactions

# %%
# What keys are available for each reactions?
data[1]["reactions"]["1576693"].keys()
# Out:
# dict_keys(['name', 'bigg_id', 'reversibility', 'label_x', 'label_y', 'gene_reaction_rule', 'genes', 'metabolites', 'segments'])

# %%
data[1]["reactions"]["1576693"]
# Out:
# {'name': 'Phosphoglycerate kinase',
#  'bigg_id': 'PGK',
#  'reversibility': True,
#  'label_x': 1065,
#  'label_y': 2715,
#  'gene_reaction_rule': 'b2926',
#  'genes': [{'bigg_id': 'b2926', 'name': 'pgk'}],
#  'metabolites': [{'coefficient': -1, 'bigg_id': '3pg_c'},
#   {'coefficient': 1, 'bigg_id': '13dpg_c'},
#   {'coefficient': -1, 'bigg_id': 'atp_c'},
#   {'coefficient': 1, 'bigg_id': 'adp_c'}],
#  'segments': {'291': {'from_node_id': '1576835',
#    'to_node_id': '1576836',
#    'b1': None,
#    'b2': None},
#   '292': {'from_node_id': '1576836',
#    'to_node_id': '1576834',
#    'b1': None,
#    'b2': None},
#   '293': {'from_node_id': '1576485',
#    'to_node_id': '1576835',
#    'b1': {'y': 2822.4341649025255, 'x': 1055},
#    'b2': {'y': 2789.230249470758, 'x': 1055}},
#   '294': {'from_node_id': '1576486',
#    'to_node_id': '1576835',
#    'b1': {'y': 2825, 'x': 1055},
#    'b2': {'y': 2790, 'x': 1055}},
#   '295': {'from_node_id': '1576834',
#    'to_node_id': '1576487',
#    'b1': {'y': 2650, 'x': 1055},
#    'b2': {'y': 2615, 'x': 1055}},
#   '296': {'from_node_id': '1576834',
#    'to_node_id': '1576488',
#    'b1': {'y': 2650.769750529242, 'x': 1055},
#    'b2': {'y': 2617.5658350974745, 'x': 1055}}}}

# %%
model.reactions.rxn12008_c
# Out:
# <Reaction rxn12008_c at 0x7f981e8450a0>

# %%
reaction_model = {}
for r in model.reactions:
    reaction_model[r.id] = {"name":r.name, "metabolites":[m.id for m in r.metabolites]}
#reaction_model

reaction_map = {}
for r in data[1]["reactions"]:
    reaction_map[data[1]["reactions"][r]["bigg_id"]] = {
        "name" : data[1]["reactions"][r]["name"],
        "metabolites": [i["bigg_id"] for i in data[1]["reactions"][r]["metabolites"]],
        "node": r}
#reaction_map

# %%
mismatch_reactions = []
for k in reaction_map.keys():
    if not k in reaction_model.keys():
        mismatch_reactions.append(k)

# %%
reaction_table = []
not_found = {}
for k in mismatch_reactions:
    print("searching for", k, "...")
    query = set(reaction_map[k]["metabolites"])
    for r in reaction_model:
        target = set(reaction_model[r]["metabolites"])
        if query == target:
            print(k, r)
            reaction_table.append({"map_id":k,
                                   "map_name": reaction_map[k]["name"],
                                   "map_metabolites": reaction_map[k]["metabolites"],
                                   "map_node": reaction_map[k]["node"],
                                   "model_id":r,
                                   "model_name": reaction_model[r]["name"],
                                   "model_metabolites": reaction_model[r]["metabolites"],
                                   })
        else:
            not_found[k] = "Not Found"
    print("----------")
# Out:
# searching for PGK ...
# ----------
# searching for GND ...
# ----------
# searching for O2t ...
# O2t rxn05468_c
# ----------
# searching for THD2 ...
# THD2 rxn10125_c
# ----------
# searching for FUM ...
# FUM rxn00799_c
# ----------
# searching for ICDHyr ...
# ----------
# searching for PDH ...
# PDH rDB00149_c
# ----------
# searching for PPC ...
# PPC rxn00251_c
# ----------
# searching for ENO ...
# ENO rxn00459_c
# ----------
# searching for PGI ...
# PGI rxn00558_c
# ----------
# searching for NH4t ...
# NH4t rxn05466_c
# ----------
# searching for FBP ...
# ----------
# searching for ICL ...
# ICL rxn00336_c
# ----------
# searching for ADK1 ...
# ADK1 rxn00097_c
# ----------
# searching for EX_gln__L_e ...
# EX_gln__L_e EX_gln_L_e
# ----------
# searching for TALA ...
# TALA rxn01333_c
# ----------
# searching for PYK ...
# ----------
# searching for GLUt2r ...
# GLUt2r rxn05297_c
# ----------
# searching for EX_lac__D_e ...
# EX_lac__D_e EX_lac_D_e
# ----------
# searching for RPE ...
# RPE rxn01116_c
# ----------
# searching for SUCOAS ...
# SUCOAS rxn00285_c
# ----------
# searching for PFK ...
# ----------
# searching for EX_glu__L_e ...
# EX_glu__L_e EX_glu_L_e
# ----------
# searching for TKT2 ...
# TKT2 rxn00785_c
# ----------
# searching for GLNS ...
# GLNS rxn00187_c
# ----------
# searching for NADTRHD ...
# NADTRHD rxn00083_c
# ----------
# searching for AKGDH ...
# AKGDH rDB00036_c
# ----------
# searching for PFL ...
# PFL rxn00157_c
# ----------
# searching for PPCK ...
# ----------
# searching for PIt2r ...
# PIt2r rxn05312_c
# ----------
# searching for AKGt2r ...
# AKGt2r rDB00145_c
# ----------
# searching for FBA ...
# FBA rxn00786_c
# ----------
# searching for TPI ...
# TPI rxn00747_c
# ----------
# searching for CYTBD ...
# CYTBD rxn10113_c
# ----------
# searching for RPI ...
# RPI rxn00777_c
# ----------
# searching for MALS ...
# MALS rxn00330_c
# ----------
# searching for PTAr ...
# ----------
# searching for GLNabc ...
# GLNabc rDB00147_c
# ----------
# searching for ME1 ...
# ----------
# searching for G6PDH2r ...
# G6PDH2r rxn00604_c
# ----------
# searching for GLUN ...
# GLUN rxn00189_c
# ----------
# searching for ATPM ...
# ATPM rxn00062_c
# ----------
# searching for LDH_D ...
# LDH_D rDB00071_c
# ----------
# searching for MDH ...
# MDH rxn00248_c
# ----------
# searching for H2Ot ...
# H2Ot rxn05319_c
# ----------
# searching for TKT1 ...
# TKT1 rxn01200_c
# ----------
# searching for CO2t ...
# CO2t rxn05467_c
# ----------
# searching for PPS ...
# PPS rxn00147_c
# ----------
# searching for EX_glc__D_e ...
# EX_glc__D_e EX_glc_D_e
# ----------
# searching for ETOHt2r ...
# ETOHt2r rDB00146_c
# ----------
# searching for PGM ...
# PGM rxn01106_c
# ----------
# searching for ACKr ...
# ----------
# searching for GLUSy ...
# GLUSy rxn00085_c
# ----------
# searching for FUMt2_2 ...
# FUMt2_2 rxn05561_c
# FUMt2_2 rxn10152_c
# ----------
# searching for ACt2r ...
# ACt2r rDB00144_c
# ----------
# searching for GLCpts ...
# GLCpts rxn05226_c
# ----------
# searching for SUCCt3 ...
# SUCCt3 rxn10154_c
# SUCCt3 rxn05654_c
# ----------
# searching for PGL ...
# PGL rxn01476_c
# ----------
# searching for GAPD ...
# ----------
# searching for SUCCt2_2 ...
# SUCCt2_2 rxn10154_c
# SUCCt2_2 rxn05654_c
# ----------
# searching for GLUDy ...
# ----------
# searching for ATPS4r ...
# ATPS4r rxn10042_c
# ----------
# searching for CS ...
# CS rxn00256_c
# ----------
# searching for PYRt2 ...
# PYRt2 rDB00150_c
# ----------
# searching for ME2 ...
# ME2 rxn00161_c
# ----------
# searching for ACALD ...
# ACALD rxn00171_c
# ----------
# searching for ACALDt ...
# ACALDt rDB00143_c
# ----------
# searching for ALCD2x ...
# ALCD2x rxn00543_c
# ----------
# searching for FORt2 ...
# FORt2 rxn05559_c
# ----------
# searching for FORti ...
# ----------
# searching for FRD7 ...
# FRD7 rxn09272_c
# ----------
# searching for FRUpts2 ...
# ----------
# searching for MALt2_2 ...
# MALt2_2 rxn10153_c
# ----------
# searching for EX_mal__L_e ...
# EX_mal__L_e EX_mal_L_e
# ----------
# searching for NADH16 ...
# NADH16 rxn10122_c
# ----------
# searching for SUCDi ...
# SUCDi rxn09272_c
# ----------
# searching for D_LACt2 ...
# ----------
# searching for BIOMASS_Ecoli_core_w_GAM ...
# ----------
# searching for ACONTa ...
# ACONTa rxn00974_c
# ----------
# searching for ACONTb ...
# ACONTb rxn01388_c
# ----------
# searching for DDPA ...
# ----------
# searching for DHQS ...
# ----------
# searching for DHQD ...
# DHQD rxn02213_c
# ----------
# searching for SHK3Dr ...
# SHK3Dr rxn01740_c
# ----------
# searching for SHKK ...
# ----------
# searching for PSCVT ...
# ----------
# searching for CHORS ...
# ----------
# searching for CHORM ...
# CHORM rDB00002_c
# ----------
# searching for PPND ...
# PPND rxn01268_c
# ----------
# searching for PPNDH ...
# PPNDH rxn01000_c
# ----------
# searching for ANS ...
# ANS rxn00727_c
# ----------
# searching for PHETA1 ...
# PHETA1 rxn00493_c
# ----------
# searching for TYRTA ...
# TYRTA rxn00527_c
# ----------
# searching for ANPRT ...
# ANPRT rxn00791_c
# ----------
# searching for PRAIi ...
# PRAIi rxn02508_c
# ----------
# searching for IGPS ...
# IGPS rxn02507_c
# ----------
# searching for PHEt2r ...
# ----------
# searching for EX_phe ...
# EX_phe EX_phe_L_e
# ----------
# searching for TYRt2r ...
# TYRt2r rDB00152_c
# ----------
# searching for EX_tyr ...
# EX_tyr EX_tyr_L_e
# ----------
# searching for TRPS1 ...
# TRPS1 rxn01964_c
# ----------
# searching for TRPS3 ...
# TRPS3 rxn01682_c
# ----------
# searching for TRPS2 ...
# TRPS2 rxn00474_c
# ----------
# searching for TRPAS2 ...
# TRPAS2 rxn00473_c
# ----------
# searching for TRPt2r ...
# TRPt2r rDB00151_c
# ----------
# searching for EX_trp ...
# EX_trp EX_trp_L_e
# ----------
# searching for rxnvio1 ...
# rxnvio1 rDB00091_c
# ----------
# searching for rxnvio2 ...
# rxnvio2 rDB00092_c
# ----------
# searching for rxnvio6 ...
# ----------
# searching for rxnvio3 ...
# rxnvio3 rDB00093_c
# ----------
# searching for rxnvio4 ...
# rxnvio4 rDB00094_c
# ----------
# searching for rxnvio5 ...
# rxnvio5 rDB00095_c
# ----------
# searching for DF_chpy ...
# ----------
# searching for Ex_chpy_e ...
# ----------
# searching for rxnvio7 ...
# rxnvio7 rDB00096_c
# ----------
# searching for rxnvio8 ...
# rxnvio8 rDB00097_c
# ----------
# searching for DF_dvio ...
# ----------
# searching for Ex_dvio_e ...
# Ex_dvio_e EX_dvio_e
# ----------
# searching for rxnvio9 ...
# ----------
# searching for DF_provio ...
# DF_provio rDB00100_c
# ----------
# searching for Ex_provio_e ...
# Ex_provio_e EX_prodvio_e
# ----------
# searching for DF_vio ...
# ----------
# searching for Ex_vio_e ...
# Ex_vio_e EX_vio_e
# ----------

# %%
df_matching_reactions = pd.DataFrame(reaction_table)
# more than 1 match
drop = df_matching_reactions.map_id.value_counts()[df_matching_reactions.map_id.value_counts() > 1]
idx_filter = []
for idx in df_matching_reactions.index:
    if not df_matching_reactions.loc[idx, "map_id"] in drop:
        idx_filter.append(idx)
df_matching_reactions.loc[idx_filter, :]
# Out:
#          map_id                         map_name  \
# 0           O2t         O2 transport  diffusion
# 1          THD2          NAD P  transhydrogenase
# 2           FUM                         Fumarase
# 3           PDH           Pyruvate dehydrogenase
# 4           PPC  Phosphoenolpyruvate carboxylase
# ..          ...                              ...
# 93      rxnvio8                          rxnvio8
# 94    Ex_dvio_e                       Ex_dvio[e]
# 95    DF_provio                        DF_provio
# 96  Ex_provio_e                     Ex_provio[e]
# 97     Ex_vio_e                        Ex_vio[e]
#
#                                       map_metabolites map_node      model_id  \
# 0                                        [o2_c, o2_e]  1576695    rxn05468_c
# 1          [h_e, nadp_c, nadh_c, nadph_c, h_c, nad_c]  1576696    rxn10125_c
# 2                            [fum_c, h2o_c, mal__L_c]  1576697    rxn00799_c
# 3       [nadh_c, coa_c, pyr_c, accoa_c, nad_c, co2_c]  1576699    rDB00149_c
# 4             [h2o_c, oaa_c, h_c, pep_c, pi_c, co2_c]  1576700    rxn00251_c
# ..                                                ...      ...           ...
# 93  [o2_c, h2o_c, mDB_dvio_c, h_c, mDB_dvnate_c, c...  1577640    rDB00097_c
# 94                                       [mDB_dvio_e]  1577642     EX_dvio_e
# 95                     [mDB_prodvio_c, mDB_prodvio_e]  1577644    rDB00100_c
# 96                                    [mDB_prodvio_e]  1577645  EX_prodvio_e
# 97                                        [mDB_vio_e]  1577647      EX_vio_e
#
#                                            model_name  \
# 0                          O2 transport via diffusion
# 1                               NADP transhydrogenase
# 2                                S-Malate hydro-lyase
# 3                              pyruvate dehydrogenase
# 4   Orthophosphate oxaloacetate carboxyl-lyase pho...
# ..                                                ...
# 93               Deoxyviolacein spontaneous synthesis
# 94                            Deoxyviolacein Exchange
# 95                     Diffusion of prodeoxyviolacein
# 96                         Prodeoxyviolacein Exchange
# 97                                 Violacein Exchange
#
#                                     model_metabolites
# 0                                        [o2_e, o2_c]
# 1          [nadh_c, nadp_c, h_e, h_c, nad_c, nadph_c]
# 2                            [mal__L_c, fum_c, h2o_c]
# 3       [coa_c, nad_c, pyr_c, co2_c, accoa_c, nadh_c]
# 4             [co2_c, h2o_c, pep_c, h_c, pi_c, oaa_c]
# ..                                                ...
# 93  [h_c, o2_c, mDB_dvnate_c, co2_c, h2o_c, mDB_dv...
# 94                                       [mDB_dvio_e]
# 95                     [mDB_prodvio_c, mDB_prodvio_e]
# 96                                    [mDB_prodvio_e]
# 97                                        [mDB_vio_e]
#
# [92 rows x 7 columns]

# %%
#to do
## replace model reaction id with map
# load Chromobacterium model
model = load_model('../models/iDB858_updated1.xml')
for idx in df_matching_reactions.loc[idx_filter, :].index:
    target_model = df_matching_reactions.loc[idx, "model_id"]
    try:
        model.reactions.get_by_id(target_model).id = df_matching_reactions.loc[idx, "map_id"]
    except KeyError:
        print(target_model)   
    data[1]["reactions"][df_matching_reactions.loc[idx, "map_node"]]["name"] = df_matching_reactions.loc[idx, "model_name"]

with open('../maps/escher_map.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
# Out:
# rxn09272_c

# %%
# simulasi model
s = fba(model)
flux = s.fluxes.to_frame()
s.objective_value
# Out:
# 0.2515998481207547

# %%
# map from author
builder_scratch = Builder(
    map_json = '../maps/escher_map.json',
    model = model,
    reaction_data = s.fluxes
)
builder_scratch
# Out:
# Builder(reaction_data={'rxn12008_c': 0.00233685938934557, 'rxn00541_c': 0.0, 'rxn00225_c': 0.0, 'rxn01674_c': …

# %% [markdown]
# ## Final Cleaning

# %%
# double reaction with the same molecules, decide which one is which
drop
# Out:
# SUCCt2_2    2
# SUCCt3      2
# FUMt2_2     2
# Name: map_id, dtype: int64

# %%
drop = df_matching_reactions.map_id.value_counts()[df_matching_reactions.map_id.value_counts() > 1]
idx_filter = []
for idx in df_matching_reactions.index:
    if df_matching_reactions.loc[idx, "map_id"] in drop:
        idx_filter.append(idx)
df_matching_reactions.loc[idx_filter, :].to_csv("../tables/double_reactions.csv")

# %%
df_matching_reactions.loc[idx_filter, :].map_id.unique()
# Out:
# array(['FUMt2_2', 'SUCCt3', 'SUCCt2_2'], dtype=object)

# %%
df_matching_reactions.loc[idx_filter, :].model_id.unique()
# Out:
# array(['rxn05561_c', 'rxn10152_c', 'rxn10154_c', 'rxn05654_c'],
#       dtype=object)

# %%
reaction_model = {}
for r in model.reactions:
    reaction_model[r.id] = {"name":r.name, "metabolites":[m.id for m in r.metabolites]}
#reaction_model

reaction_map = {}
for r in data[1]["reactions"]:
    reaction_map[data[1]["reactions"][r]["bigg_id"]] = {
        "name" : data[1]["reactions"][r]["name"],
        "metabolites": [i["bigg_id"] for i in data[1]["reactions"][r]["metabolites"]],
        "node": r}
#reaction_map

mismatch_reactions = []
for k in reaction_map.keys():
    if not k in reaction_model.keys():
        mismatch_reactions.append(k)
print(len(mismatch_reactions))
mismatch_reactions
# Out:
# 32
# ['PGK',
#  'GND',
#  'ICDHyr',
#  'FBP',
#  'PYK',
#  'PFK',
#  'PPCK',
#  'PTAr',
#  'ME1',
#  'ACKr',
#  'FUMt2_2',
#  'SUCCt3',
#  'GAPD',
#  'SUCCt2_2',
#  'GLUDy',
#  'FORti',
#  'FRUpts2',
#  'SUCDi',
#  'D_LACt2',
#  'BIOMASS_Ecoli_core_w_GAM',
#  'DDPA',
#  'DHQS',
#  'SHKK',
#  'PSCVT',
#  'CHORS',
#  'PHEt2r',
#  'rxnvio6',
#  'DF_chpy',
#  'Ex_chpy_e',
#  'DF_dvio',
#  'rxnvio9',
#  'DF_vio']

# %%
df_missing_reactions = []
for i in data[1]["reactions"]:
    if data[1]["reactions"][i]["bigg_id"] in mismatch_reactions:
        df_missing_reactions.append(data[1]["reactions"][i])
df_missing = pd.DataFrame(df_missing_reactions)
df_missing = df_missing.loc[:, ["name", "bigg_id", "gene_reaction_rule", "genes", "metabolites"]]
df_missing.to_csv("../tables/missing_on_map.csv")

# %%
model_reactions = []
for i in model.reactions:
    d = {"name":i.name, 
         "bigg_id":i.id,
         "metabolites":[{"coefficient":i.get_coefficient(x), "bigg_id":x.id} for x in i.metabolites]}
    model_reactions.append(d)
df_model_reactions = pd.DataFrame(model_reactions)
df_model_reactions.to_csv("../tables/all_reactions_in_model.csv")
